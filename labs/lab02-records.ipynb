# %% [markdown]
# COMP 215 - LAB 2 Records (NEO)
# ----------------
# #### Name:
# #### Date:
#
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
#
# **Building on new concepts from lab 1**:
#   * `datetime.date` objects represent a calendar date
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# **New Python Concepts**:
#   * *f-string* simplifies string formatting operations
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/)
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# You should register for your own API key, (but may use the DEMO_KEY to get started).
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the stringg
print(formatted_date)
# Out:
# 2024-01-22 <class 'datetime.date'>
# Today is: 2024-01-22

# %% [markdown]
# ### Make a query
#
# Let's get some data from the NEO database...
# Here's a query that gets the observation "feed" for today.
# (Note: I hard-coded the date below to lock down the data for the lab - ideally used `today()` so the notebook is always up-to-date.)

# %%
API_KEY = 'DEMO_KEY'  # substitute your API key here

today = str(datetime.date.today())  #  Future enhancement:  str(datetime.date.today())   # Today's date as a string!
# Use an f-string here to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

response = requests.request("GET", url, headers={}, data={})

data = json.loads(response.text)  # recall json.loads for lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(data)
# Out:
# 8 Near Earth Objects found for 2024-01-22
# {'element_count': 8,
#  'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-23&end_date=2024-01-23&detailed=false&api_key=DEMO_KEY',
#            'prev': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-21&end_date=2024-01-21&detailed=false&api_key=DEMO_KEY',
#            'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-22&end_date=2024-01-22&detailed=false&api_key=DEMO_KEY'},
#  'near_earth_objects': {'2024-01-22': [{'absolute_magnitude_h': 25.0,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '03:21',
#                                                                  'epoch_date_close_approach': 1705893660000,
#                                                                  'miss_distance': {'astronomical': '0.3145857376',
#                                                                                    'kilometers': '47061356.277338912',
#                                                                                    'lunar': '122.3738519264',
#                                                                                    'miles': '29242570.7947125056'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '68893.8633515718',
#                                                                                        'kilometers_per_second': '19.1371842643',
#                                                                                        'miles_per_hour': '42807.9674808697'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 194.9956979785,
#                                                                         'estimated_diameter_min': 87.2047272},
#                                                                'kilometers': {'estimated_diameter_max': 0.0594346868,
#                                                                               'estimated_diameter_min': 0.02658},
#                                                                'meters': {'estimated_diameter_max': 59.4346868419,
#                                                                           'estimated_diameter_min': 26.58},
#                                                                'miles': {'estimated_diameter_max': 0.0369309908,
#                                                                          'estimated_diameter_min': 0.0165160412}},
#                                         'id': '3183847',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3183847?api_key=DEMO_KEY'},
#                                         'name': '(2004 LO2)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3183847',
#                                         'neo_reference_id': '3183847'},
#                                        {'absolute_magnitude_h': 21.27,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '09:40',
#                                                                  'epoch_date_close_approach': 1705916400000,
#                                                                  'miss_distance': {'astronomical': '0.3959001387',
#                                                                                    'kilometers': '59225817.482224569',
#                                                                                    'lunar': '154.0051539543',
#                                                                                    'miles': '36801216.4883702922'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '64423.9608461795',
#                                                                                        'kilometers_per_second': '17.8955446795',
#                                                                                        'miles_per_hour': '40030.5438935608'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 1086.4882401667,
#                                                                         'estimated_diameter_min': 485.8923123534},
#                                                                'kilometers': {'estimated_diameter_max': 0.331161605,
#                                                                               'estimated_diameter_min': 0.1480999721},
#                                                                'meters': {'estimated_diameter_max': 331.1616050056,
#                                                                           'estimated_diameter_min': 148.0999720661},
#                                                                'miles': {'estimated_diameter_max': 0.2057742177,
#                                                                          'estimated_diameter_min': 0.0920250277}},
#                                         'id': '3557196',
#                                         'is_potentially_hazardous_asteroid': True,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3557196?api_key=DEMO_KEY'},
#                                         'name': '(2011 CC22)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3557196',
#                                         'neo_reference_id': '3557196'},
#                                        {'absolute_magnitude_h': 28.1,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '14:13',
#                                                                  'epoch_date_close_approach': 1705932780000,
#                                                                  'miss_distance': {'astronomical': '0.092898524',
#                                                                                    'kilometers': '13897421.31654388',
#                                                                                    'lunar': '36.137525836',
#                                                                                    'miles': '8635457.174630344'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '13926.6467436716',
#                                                                                        'kilometers_per_second': '3.8685129844',
#                                                                                        'miles_per_hour': '8653.4766946997'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 46.7762099378,
#                                                                         'estimated_diameter_min': 20.9189570301},
#                                                                'kilometers': {'estimated_diameter_max': 0.0142573883,
#                                                                               'estimated_diameter_min': 0.0063760979},
#                                                                'meters': {'estimated_diameter_max': 14.2573883328,
#                                                                           'estimated_diameter_min': 6.3760978988},
#                                                                'miles': {'estimated_diameter_max': 0.0088591276,
#                                                                          'estimated_diameter_min': 0.0039619223}},
#                                         'id': '3790065',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3790065?api_key=DEMO_KEY'},
#                                         'name': '(2017 WT28)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3790065',
#                                         'neo_reference_id': '3790065'},
#                                        {'absolute_magnitude_h': 27.0,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '10:24',
#                                                                  'epoch_date_close_approach': 1705919040000,
#                                                                  'miss_distance': {'astronomical': '0.4100744842',
#                                                                                    'kilometers': '61346269.377668654',
#                                                                                    'lunar': '159.5189743538',
#                                                                                    'miles': '38118804.1988452652'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '54835.6900340318',
#                                                                                        'kilometers_per_second': '15.2321361206',
#                                                                                        'miles_per_hour': '34072.7652880905'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 77.6291855923,
#                                                                         'estimated_diameter_min': 34.7168272045},
#                                                                'kilometers': {'estimated_diameter_max': 0.023661375,
#                                                                               'estimated_diameter_min': 0.0105816886},
#                                                                'meters': {'estimated_diameter_max': 23.6613750114,
#                                                                           'estimated_diameter_min': 10.5816885933},
#                                                                'miles': {'estimated_diameter_max': 0.0147024923,
#                                                                          'estimated_diameter_min': 0.0065751544}},
#                                         'id': '3838241',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3838241?api_key=DEMO_KEY'},
#                                         'name': '(2019 CF4)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3838241',
#                                         'neo_reference_id': '3838241'},
#                                        {'absolute_magnitude_h': 27.16,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '06:59',
#                                                                  'epoch_date_close_approach': 1705906740000,
#                                                                  'miss_distance': {'astronomical': '0.062965615',
#                                                                                    'kilometers': '9419521.88724005',
#                                                                                    'lunar': '24.493624235',
#                                                                                    'miles': '5853019.49261069'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '23724.3884253235',
#                                                                                        'kilometers_per_second': '6.5901078959',
#                                                                                        'miles_per_hour': '14741.4123523906'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 72.1149040484,
#                                                                         'estimated_diameter_min': 32.2507655286},
#                                                                'kilometers': {'estimated_diameter_max': 0.0219806221,
#                                                                               'estimated_diameter_min': 0.009830033},
#                                                                'meters': {'estimated_diameter_max': 21.9806220506,
#                                                                           'estimated_diameter_min': 9.8300330186},
#                                                                'miles': {'estimated_diameter_max': 0.0136581211,
#                                                                          'estimated_diameter_min': 0.0061080974}},
#                                         'id': '54101721',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54101721?api_key=DEMO_KEY'},
#                                         'name': '(2020 YK3)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54101721',
#                                         'neo_reference_id': '54101721'},
#                                        {'absolute_magnitude_h': 27.15,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '01:21',
#                                                                  'epoch_date_close_approach': 1705886460000,
#                                                                  'miss_distance': {'astronomical': '0.361889438',
#                                                                                    'kilometers': '54137889.10029706',
#                                                                                    'lunar': '140.774991382',
#                                                                                    'miles': '33639724.392177028'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '59832.729115079',
#                                                                                        'kilometers_per_second': '16.620202532',
#                                                                                        'miles_per_hour': '37177.7310437556'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 72.4477713214,
#                                                                         'estimated_diameter_min': 32.3996282986},
#                                                                'kilometers': {'estimated_diameter_max': 0.02208208,
#                                                                               'estimated_diameter_min': 0.0098754064},
#                                                                'meters': {'estimated_diameter_max': 22.0820799921,
#                                                                           'estimated_diameter_min': 9.8754063894},
#                                                                'miles': {'estimated_diameter_max': 0.0137211641,
#                                                                          'estimated_diameter_min': 0.0061362911}},
#                                         'id': '54212941',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54212941?api_key=DEMO_KEY'},
#                                         'name': '(2021 UB3)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54212941',
#                                         'neo_reference_id': '54212941'},
#                                        {'absolute_magnitude_h': 21.374,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '05:32',
#                                                                  'epoch_date_close_approach': 1705901520000,
#                                                                  'miss_distance': {'astronomical': '0.1336593902',
#                                                                                    'kilometers': '19995160.079418874',
#                                                                                    'lunar': '51.9935027878',
#                                                                                    'miles': '12424416.3455095012'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '77034.0362201748',
#                                                                                        'kilometers_per_second': '21.3983433945',
#                                                                                        'miles_per_hour': '47865.9543391414'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 1035.6786653344,
#                                                                         'estimated_diameter_min': 463.1695797068},
#                                                                'kilometers': {'estimated_diameter_max': 0.3156748471,
#                                                                               'estimated_diameter_min': 0.1411740834},
#                                                                'meters': {'estimated_diameter_max': 315.6748470923,
#                                                                           'estimated_diameter_min': 141.1740833771},
#                                                                'miles': {'estimated_diameter_max': 0.1961511954,
#                                                                          'estimated_diameter_min': 0.0877214814}},
#                                         'id': '54418440',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54418440?api_key=DEMO_KEY'},
#                                         'name': '(2023 YU1)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54418440',
#                                         'neo_reference_id': '54418440'},
#                                        {'absolute_magnitude_h': 26.886,
#                                         'close_approach_data': [{'close_approach_date': '2024-01-22',
#                                                                  'close_approach_date_full': '2024-Jan-22 '
#                                                                                              '03:31',
#                                                                  'epoch_date_close_approach': 1705894260000,
#                                                                  'miss_distance': {'astronomical': '0.0200370019',
#                                                                                    'kilometers': '2997492.805425953',
#                                                                                    'lunar': '7.7943937391',
#                                                                                    'miles': '1862555.6614380314'},
#                                                                  'orbiting_body': 'Earth',
#                                                                  'relative_velocity': {'kilometers_per_hour': '21148.3826831448',
#                                                                                        'kilometers_per_second': '5.8745507453',
#                                                                                        'miles_per_hour': '13140.7825622018'}}],
#                                         'estimated_diameter': {'feet': {'estimated_diameter_max': 81.8135108753,
#                                                                         'estimated_diameter_min': 36.588114359},
#                                                                'kilometers': {'estimated_diameter_max': 0.0249367573,
#                                                                               'estimated_diameter_min': 0.0111520569},
#                                                                'meters': {'estimated_diameter_max': 24.9367573168,
#                                                                           'estimated_diameter_min': 11.1520568998},
#                                                                'miles': {'estimated_diameter_max': 0.0154949778,
#                                                                          'estimated_diameter_min': 0.0069295647}},
#                                         'id': '54421078',
#                                         'is_potentially_hazardous_asteroid': False,
#                                         'is_sentry_object': False,
#                                         'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54421078?api_key=DEMO_KEY'},
#                                         'name': '(2024 BM)',
#                                         'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54421078',
#                                         'neo_reference_id': '54421078'}]}}

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a Comp115-style list accumulator *loop*:

# %%
hazards =  []
for item in neos:
  if item['is_potentially_hazardous_asteroid'] is True:
    hazards.append(item)
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 1 potentially hazardous asteroids identified.

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the accumulator loop above** as a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0)
# Notice how this provides a concise way to "filter" items of interest from a larger data set.

# %%
hazards = [item for item in neos if item['is_potentially_hazardous_asteroid']]
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 1 potentially hazardous asteroids identified.

# %% [markdown]
# ## Fetch Complete Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the first hazardous asteroid...

# %%
id = hazards[0]['id']
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 21.27,
#  'close_approach_data': [{'close_approach_date': '1904-02-05',
#                           'close_approach_date_full': '1904-Feb-05 21:06',
#                           'epoch_date_close_approach': -2079744840000,
#                           'miss_distance': {'astronomical': '0.3141742395',
#                                             'kilometers': '46999797.038069865',
#                                             'lunar': '122.2137791655',
#                                             'miles': '29204319.657159537'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63774.5265661511',
#                                                 'kilometers_per_second': '17.7151462684',
#                                                 'miles_per_hour': '39627.0106877287'}},
#                          {'close_approach_date': '1904-08-11',
#                           'close_approach_date_full': '1904-Aug-11 17:41',
#                           'epoch_date_close_approach': -2063513940000,
#                           'miss_distance': {'astronomical': '0.2138645918',
#                                             'kilometers': '31993687.401699466',
#                                             'lunar': '83.1933262102',
#                                             'miles': '19879955.5056299908'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '70622.5862696879',
#                                                 'kilometers_per_second': '19.6173850749',
#                                                 'miles_per_hour': '43882.1286740736'}},
#                          {'close_approach_date': '1910-02-12',
#                           'close_approach_date_full': '1910-Feb-12 02:19',
#                           'epoch_date_close_approach': -1889818860000,
#                           'miss_distance': {'astronomical': '0.4781143791',
#                                             'kilometers': '71524892.729732517',
#                                             'lunar': '185.9864934699',
#                                             'miles': '44443507.4694300546'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69517.036421132',
#                                                 'kilometers_per_second': '19.3102878948',
#                                                 'miles_per_hour': '43195.1829917862'}},
#                          {'close_approach_date': '1910-07-29',
#                           'close_approach_date_full': '1910-Jul-29 04:44',
#                           'epoch_date_close_approach': -1875381360000,
#                           'miss_distance': {'astronomical': '0.1007812258',
#                                             'kilometers': '15076656.715669046',
#                                             'lunar': '39.2038968362',
#                                             'miles': '9368200.0739069948'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66440.7067767185',
#                                                 'kilometers_per_second': '18.4557518824',
#                                                 'miles_per_hour': '41283.6713857893'}},
#                          {'close_approach_date': '1916-07-13',
#                           'close_approach_date_full': '1916-Jul-13 22:32',
#                           'epoch_date_close_approach': -1687310880000,
#                           'miss_distance': {'astronomical': '0.4192548462',
#                                             'kilometers': '62719631.978697594',
#                                             'lunar': '163.0901351718',
#                                             'miles': '38972172.1479270372'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '77673.7347015668',
#                                                 'kilometers_per_second': '21.5760374171',
#                                                 'miles_per_hour': '48263.4380983152'}},
#                          {'close_approach_date': '1917-01-24',
#                           'close_approach_date_full': '1917-Jan-24 17:17',
#                           'epoch_date_close_approach': -1670481780000,
#                           'miss_distance': {'astronomical': '0.3301387873',
#                                             'kilometers': '49388059.384463051',
#                                             'lunar': '128.4239882597',
#                                             'miles': '30688317.0653340638'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63103.4762028462',
#                                                 'kilometers_per_second': '17.5287433897',
#                                                 'miles_per_hour': '39210.0460883741'}},
#                          {'close_approach_date': '1923-02-01',
#                           'close_approach_date_full': '1923-Feb-01 16:11',
#                           'epoch_date_close_approach': -1480492140000,
#                           'miss_distance': {'astronomical': '0.266735382',
#                                             'kilometers': '39903045.00083634',
#                                             'lunar': '103.760063598',
#                                             'miles': '24794602.422527892'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62328.8183793242',
#                                                 'kilometers_per_second': '17.3135606609',
#                                                 'miles_per_hour': '38728.7038424196'}},
#                          {'close_approach_date': '1923-08-20',
#                           'close_approach_date_full': '1923-Aug-20 17:51',
#                           'epoch_date_close_approach': -1463206140000,
#                           'miss_distance': {'astronomical': '0.3961210848',
#                                             'kilometers': '59258870.548169376',
#                                             'lunar': '154.0911019872',
#                                             'miles': '36821754.7111783488'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79495.0862110218',
#                                                 'kilometers_per_second': '22.081968392',
#                                                 'miles_per_hour': '49395.1550959541'}},
#                          {'close_approach_date': '1929-02-08',
#                           'close_approach_date_full': '1929-Feb-08 03:46',
#                           'epoch_date_close_approach': -1290543240000,
#                           'miss_distance': {'astronomical': '0.378015964',
#                                             'kilometers': '56550383.04039668',
#                                             'lunar': '147.048209996',
#                                             'miles': '35138778.614486984'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65810.2150051168',
#                                                 'kilometers_per_second': '18.2806152792',
#                                                 'miles_per_hour': '40891.9083180405'}},
#                          {'close_approach_date': '1929-08-05',
#                           'close_approach_date_full': '1929-Aug-05 21:14',
#                           'epoch_date_close_approach': -1275101160000,
#                           'miss_distance': {'astronomical': '0.0780656346',
#                                             'kilometers': '11678452.656358302',
#                                             'lunar': '30.3675318594',
#                                             'miles': '7256653.9851444876'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66871.918448014',
#                                                 'kilometers_per_second': '18.5755329022',
#                                                 'miles_per_hour': '41551.6095489896'}},
#                          {'close_approach_date': '1935-07-23',
#                           'close_approach_date_full': '1935-Jul-23 09:22',
#                           'epoch_date_close_approach': -1086964680000,
#                           'miss_distance': {'astronomical': '0.2336496757',
#                                             'kilometers': '34953493.810910759',
#                                             'lunar': '90.8897238473',
#                                             'miles': '21719093.9263321142'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69459.2574762812',
#                                                 'kilometers_per_second': '19.2942381879',
#                                                 'miles_per_hour': '43159.2814024149'}},
#                          {'close_approach_date': '1936-01-20',
#                           'close_approach_date_full': '1936-Jan-20 16:27',
#                           'epoch_date_close_approach': -1071300780000,
#                           'miss_distance': {'astronomical': '0.4241035504',
#                                             'kilometers': '63444987.799277648',
#                                             'lunar': '164.9762811056',
#                                             'miles': '39422887.3548936224'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65077.3134656554',
#                                                 'kilometers_per_second': '18.0770315182',
#                                                 'miles_per_hour': '40436.5118031457'}},
#                          {'close_approach_date': '1942-01-27',
#                           'close_approach_date_full': '1942-Jan-27 23:37',
#                           'epoch_date_close_approach': -881281380000,
#                           'miss_distance': {'astronomical': '0.2864681039',
#                                             'kilometers': '42855018.166378693',
#                                             'lunar': '111.4360924171',
#                                             'miles': '26628873.4913162434'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62332.7697114102',
#                                                 'kilometers_per_second': '17.3146582532',
#                                                 'miles_per_hour': '38731.1590465149'}},
#                          {'close_approach_date': '1948-02-04',
#                           'close_approach_date_full': '1948-Feb-04 11:31',
#                           'epoch_date_close_approach': -691331340000,
#                           'miss_distance': {'astronomical': '0.2894214169',
#                                             'kilometers': '43296827.500622003',
#                                             'lunar': '112.5849311741',
#                                             'miles': '26903401.0816015214'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63054.1447797168',
#                                                 'kilometers_per_second': '17.5150402166',
#                                                 'miles_per_hour': '39179.3934604857'}},
#                          {'close_approach_date': '1948-08-15',
#                           'close_approach_date_full': '1948-Aug-15 04:37',
#                           'epoch_date_close_approach': -674680980000,
#                           'miss_distance': {'astronomical': '0.2869866295',
#                                             'kilometers': '42932588.491679165',
#                                             'lunar': '111.6377988755',
#                                             'miles': '26677073.456395877'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '73699.5665221103',
#                                                 'kilometers_per_second': '20.4721018117',
#                                                 'miles_per_hour': '45794.0445425857'}},
#                          {'close_approach_date': '1954-02-10',
#                           'close_approach_date_full': '1954-Feb-10 15:09',
#                           'epoch_date_close_approach': -501411060000,
#                           'miss_distance': {'astronomical': '0.4335597268',
#                                             'kilometers': '64859611.647061916',
#                                             'lunar': '168.6547337252',
#                                             'miles': '40301893.8538338008'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '67709.161215189',
#                                                 'kilometers_per_second': '18.8081003376',
#                                                 'miles_per_hour': '42071.8396450712'}},
#                          {'close_approach_date': '1954-08-01',
#                           'close_approach_date_full': '1954-Aug-01 19:00',
#                           'epoch_date_close_approach': -486536400000,
#                           'miss_distance': {'astronomical': '0.0304759795',
#                                             'kilometers': '4559141.619363665',
#                                             'lunar': '11.8551560255',
#                                             'miles': '2832919.238061977'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66031.8515681274',
#                                                 'kilometers_per_second': '18.3421809911',
#                                                 'miles_per_hour': '41029.6246590956'}},
#                          {'close_approach_date': '1960-07-16',
#                           'close_approach_date_full': '1960-Jul-16 21:26',
#                           'epoch_date_close_approach': -298521240000,
#                           'miss_distance': {'astronomical': '0.3595451791',
#                                             'kilometers': '53787192.962128517',
#                                             'lunar': '139.8630746699',
#                                             'miles': '33421811.9166548546'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '74619.2626793183',
#                                                 'kilometers_per_second': '20.7275729665',
#                                                 'miles_per_hour': '46365.5079687131'}},
#                          {'close_approach_date': '1961-01-23',
#                           'close_approach_date_full': '1961-Jan-23 10:16',
#                           'epoch_date_close_approach': -282059040000,
#                           'miss_distance': {'astronomical': '0.3566079763',
#                                             'kilometers': '53347793.679490481',
#                                             'lunar': '138.7205027807',
#                                             'miles': '33148781.8629953978'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63622.0258955464',
#                                                 'kilometers_per_second': '17.672784971',
#                                                 'miles_per_hour': '39532.2527015966'}},
#                          {'close_approach_date': '1967-01-31',
#                           'close_approach_date_full': '1967-Jan-31 21:25',
#                           'epoch_date_close_approach': -92025300000,
#                           'miss_distance': {'astronomical': '0.2638075327',
#                                             'kilometers': '39465044.981875349',
#                                             'lunar': '102.6211302203',
#                                             'miles': '24522441.8309998562'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62218.356473119',
#                                                 'kilometers_per_second': '17.2828767981',
#                                                 'miles_per_hour': '38660.0671096444'}},
#                          {'close_approach_date': '1967-08-22',
#                           'close_approach_date_full': '1967-Aug-22 17:48',
#                           'epoch_date_close_approach': -74499120000,
#                           'miss_distance': {'astronomical': '0.4375157768',
#                                             'kilometers': '65451428.300675416',
#                                             'lunar': '170.1936371752',
#                                             'miles': '40669631.6701601008'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81956.682102631',
#                                                 'kilometers_per_second': '22.7657450285',
#                                                 'miles_per_hour': '50924.6950542709'}},
#                          {'close_approach_date': '1973-02-07',
#                           'close_approach_date_full': '1973-Feb-07 16:15',
#                           'epoch_date_close_approach': 97949700000,
#                           'miss_distance': {'astronomical': '0.3636585964',
#                                             'kilometers': '54402551.428629668',
#                                             'lunar': '141.4631939996',
#                                             'miles': '33804177.9371906984'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65343.8582087364',
#                                                 'kilometers_per_second': '18.1510717246',
#                                                 'miles_per_hour': '40602.1323408673'}},
#                          {'close_approach_date': '1973-08-07',
#                           'close_approach_date_full': '1973-Aug-07 05:30',
#                           'epoch_date_close_approach': 113549400000,
#                           'miss_distance': {'astronomical': '0.1039018866',
#                                             'kilometers': '15543500.924341542',
#                                             'lunar': '40.4178338874',
#                                             'miles': '9658283.6138235996'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '67360.4112928586',
#                                                 'kilometers_per_second': '18.7112253591',
#                                                 'miles_per_hour': '41855.1400058321'}},
#                          {'close_approach_date': '1979-07-23',
#                           'close_approach_date_full': '1979-Jul-23 20:47',
#                           'epoch_date_close_approach': 301610820000,
#                           'miss_distance': {'astronomical': '0.2267345273',
#                                             'kilometers': '33919002.339536851',
#                                             'lunar': '88.1997311197',
#                                             'miles': '21076290.7332005038'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69238.3140805799',
#                                                 'kilometers_per_second': '19.2328650224',
#                                                 'miles_per_hour': '43021.9957685692'}},
#                          {'close_approach_date': '1980-01-20',
#                           'close_approach_date_full': '1980-Jan-20 17:47',
#                           'epoch_date_close_approach': 317238420000,
#                           'miss_distance': {'astronomical': '0.426276532',
#                                             'kilometers': '63770061.21818684',
#                                             'lunar': '165.821570948',
#                                             'miles': '39624878.610944792'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65182.6608135275',
#                                                 'kilometers_per_second': '18.1062946704',
#                                                 'miles_per_hour': '40501.9705482721'}},
#                          {'close_approach_date': '1986-01-28',
#                           'close_approach_date_full': '1986-Jan-28 12:31',
#                           'epoch_date_close_approach': 507299460000,
#                           'miss_distance': {'astronomical': '0.2817820403',
#                                             'kilometers': '42153993.033134161',
#                                             'lunar': '109.6132136767',
#                                             'miles': '26193276.6724109818'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62277.8046205615',
#                                                 'kilometers_per_second': '17.2993901724',
#                                                 'miles_per_hour': '38697.0058765928'}},
#                          {'close_approach_date': '1992-02-05',
#                           'close_approach_date_full': '1992-Feb-05 08:32',
#                           'epoch_date_close_approach': 697278720000,
#                           'miss_distance': {'astronomical': '0.2999426471',
#                                             'kilometers': '44870781.128321677',
#                                             'lunar': '116.6776897219',
#                                             'miles': '27881410.5149540626'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63394.6729818287',
#                                                 'kilometers_per_second': '17.6096313838',
#                                                 'miles_per_hour': '39390.9844425146'}},
#                          {'close_approach_date': '1992-08-13',
#                           'close_approach_date_full': '1992-Aug-13 17:32',
#                           'epoch_date_close_approach': 713727120000,
#                           'miss_distance': {'astronomical': '0.25136645',
#                                             'kilometers': '37603885.5094615',
#                                             'lunar': '97.78154905',
#                                             'miles': '23365970.9611087'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72075.9161171632',
#                                                 'kilometers_per_second': '20.0210878103',
#                                                 'miles_per_hour': '44785.1713229117'}},
#                          {'close_approach_date': '1998-02-11',
#                           'close_approach_date_full': '1998-Feb-11 21:57',
#                           'epoch_date_close_approach': 887234220000,
#                           'miss_distance': {'astronomical': '0.4656539651',
#                                             'kilometers': '69660841.336014337',
#                                             'lunar': '181.1393924239',
#                                             'miles': '43285239.6429663706'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69003.1971163775',
#                                                 'kilometers_per_second': '19.1675547545',
#                                                 'miles_per_hour': '42875.9032304513'}},
#                          {'close_approach_date': '1998-07-30',
#                           'close_approach_date_full': '1998-Jul-30 10:34',
#                           'epoch_date_close_approach': 901794840000,
#                           'miss_distance': {'astronomical': '0.0802003909',
#                                             'kilometers': '11997807.651807383',
#                                             'lunar': '31.1979520601',
#                                             'miles': '7455091.9776245654'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66221.3024689212',
#                                                 'kilometers_per_second': '18.3948062414',
#                                                 'miles_per_hour': '41147.3420813138'}},
#                          {'close_approach_date': '2004-07-14',
#                           'close_approach_date_full': '2004-Jul-14 08:04',
#                           'epoch_date_close_approach': 1089792240000,
#                           'miss_distance': {'astronomical': '0.4179880904',
#                                             'kilometers': '62530128.009207448',
#                                             'lunar': '162.5973671656',
#                                             'miles': '38854419.8415328624'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '77665.9342493351',
#                                                 'kilometers_per_second': '21.5738706248',
#                                                 'miles_per_hour': '48258.5912006493'}},
#                          {'close_approach_date': '2005-01-25',
#                           'close_approach_date_full': '2005-Jan-25 02:50',
#                           'epoch_date_close_approach': 1106621400000,
#                           'miss_distance': {'astronomical': '0.3285259042',
#                                             'kilometers': '49146775.508144054',
#                                             'lunar': '127.7965767338',
#                                             'miles': '30538390.2167897852'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63049.0057649093',
#                                                 'kilometers_per_second': '17.5136127125',
#                                                 'miles_per_hour': '39176.2002765349'}},
#                          {'close_approach_date': '2011-02-02',
#                           'close_approach_date_full': '2011-Feb-02 11:10',
#                           'epoch_date_close_approach': 1296645000000,
#                           'miss_distance': {'astronomical': '0.2685666805',
#                                             'kilometers': '40177003.355770535',
#                                             'lunar': '104.4724387145',
#                                             'miles': '24964832.250621983'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62476.3922146499',
#                                                 'kilometers_per_second': '17.354553393',
#                                                 'miles_per_hour': '38820.4004847084'}},
#                          {'close_approach_date': '2011-08-20',
#                           'close_approach_date_full': '2011-Aug-20 01:03',
#                           'epoch_date_close_approach': 1313802180000,
#                           'miss_distance': {'astronomical': '0.3744130244',
#                                             'kilometers': '56011390.950498028',
#                                             'lunar': '145.6466664916',
#                                             'miles': '34803864.4599996664'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78171.8140536869',
#                                                 'kilometers_per_second': '21.7143927927',
#                                                 'miles_per_hour': '48572.9252379701'}},
#                          {'close_approach_date': '2017-02-09',
#                           'close_approach_date_full': '2017-Feb-09 07:02',
#                           'epoch_date_close_approach': 1486623720000,
#                           'miss_distance': {'astronomical': '0.4003230466',
#                                             'kilometers': '59887475.083270742',
#                                             'lunar': '155.7256651274',
#                                             'miles': '37212351.4570785596'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66552.8854971258',
#                                                 'kilometers_per_second': '18.4869126381',
#                                                 'miles_per_hour': '41353.3748801446'}},
#                          {'close_approach_date': '2017-08-04',
#                           'close_approach_date_full': '2017-Aug-04 07:21',
#                           'epoch_date_close_approach': 1501831260000,
#                           'miss_distance': {'astronomical': '0.0395746124',
#                                             'kilometers': '5920277.721115588',
#                                             'lunar': '15.3945242236',
#                                             'miles': '3678689.9927795944'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66299.6137780062',
#                                                 'kilometers_per_second': '18.4165593828',
#                                                 'miles_per_hour': '41196.0016833395'}},
#                          {'close_approach_date': '2023-07-21',
#                           'close_approach_date_full': '2023-Jul-21 09:35',
#                           'epoch_date_close_approach': 1689932100000,
#                           'miss_distance': {'astronomical': '0.2830473722',
#                                             'kilometers': '42343283.990217214',
#                                             'lunar': '110.1054277858',
#                                             'miles': '26310896.6190329932'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71230.0734271192',
#                                                 'kilometers_per_second': '19.7861315075',
#                                                 'miles_per_hour': '44259.5975692008'}},
#                          {'close_approach_date': '2024-01-22',
#                           'close_approach_date_full': '2024-Jan-22 09:40',
#                           'epoch_date_close_approach': 1705916400000,
#                           'miss_distance': {'astronomical': '0.3959001387',
#                                             'kilometers': '59225817.482224569',
#                                             'lunar': '154.0051539543',
#                                             'miles': '36801216.4883702922'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64423.9608461795',
#                                                 'kilometers_per_second': '17.8955446795',
#                                                 'miles_per_hour': '40030.5438935608'}},
#                          {'close_approach_date': '2030-01-29',
#                           'close_approach_date_full': '2030-Jan-29 16:16',
#                           'epoch_date_close_approach': 1895933760000,
#                           'miss_distance': {'astronomical': '0.272695431',
#                                             'kilometers': '40794655.63633197',
#                                             'lunar': '106.078522659',
#                                             'miles': '25348623.581122386'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62203.1547911771',
#                                                 'kilometers_per_second': '17.2786541087',
#                                                 'miles_per_hour': '38650.6213756622'}},
#                          {'close_approach_date': '2036-02-06',
#                           'close_approach_date_full': '2036-Feb-06 04:41',
#                           'epoch_date_close_approach': 2085885660000,
#                           'miss_distance': {'astronomical': '0.3120412453',
#                                             'kilometers': '46680705.649027511',
#                                             'lunar': '121.3840444217',
#                                             'miles': '29006045.4621052118'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63680.7789168167',
#                                                 'kilometers_per_second': '17.6891052547',
#                                                 'miles_per_hour': '39568.7595441742'}},
#                          {'close_approach_date': '2036-08-12',
#                           'close_approach_date_full': '2036-Aug-12 12:29',
#                           'epoch_date_close_approach': 2102156940000,
#                           'miss_distance': {'astronomical': '0.2215865431',
#                                             'kilometers': '33148874.868423197',
#                                             'lunar': '86.1971652659',
#                                             'miles': '20597755.7126142386'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '70855.5272603126',
#                                                 'kilometers_per_second': '19.6820909056',
#                                                 'miles_per_hour': '44026.8691468315'}},
#                          {'close_approach_date': '2042-02-12',
#                           'close_approach_date_full': '2042-Feb-12 12:51',
#                           'epoch_date_close_approach': 2275822260000,
#                           'miss_distance': {'astronomical': '0.4770232437',
#                                             'kilometers': '71361661.198010919',
#                                             'lunar': '185.5620417993',
#                                             'miles': '44342080.0988679222'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69435.3487186897',
#                                                 'kilometers_per_second': '19.2875968663',
#                                                 'miles_per_hour': '43144.4254302325'}},
#                          {'close_approach_date': '2042-07-29',
#                           'close_approach_date_full': '2042-Jul-29 19:25',
#                           'epoch_date_close_approach': 2290274700000,
#                           'miss_distance': {'astronomical': '0.096501759',
#                                             'kilometers': '14436457.59765333',
#                                             'lunar': '37.539184251',
#                                             'miles': '8970398.788262754'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66375.580038435',
#                                                 'kilometers_per_second': '18.4376611218',
#                                                 'miles_per_hour': '41243.2041633265'}},
#                          {'close_approach_date': '2048-07-14',
#                           'close_approach_date_full': '2048-Jul-14 09:41',
#                           'epoch_date_close_approach': 2478332460000,
#                           'miss_distance': {'astronomical': '0.4193929366',
#                                             'kilometers': '62740290.008405042',
#                                             'lunar': '163.1438523374',
#                                             'miles': '38985008.4523598996'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '77726.3147641962',
#                                                 'kilometers_per_second': '21.5906429901',
#                                                 'miles_per_hour': '48296.1093044529'}},
#                          {'close_approach_date': '2049-01-25',
#                           'close_approach_date_full': '2049-Jan-25 06:46',
#                           'epoch_date_close_approach': 2495169960000,
#                           'miss_distance': {'astronomical': '0.3286459044',
#                                             'kilometers': '49164727.282463628',
#                                             'lunar': '127.8432568116',
#                                             'miles': '30549544.9321009464'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63044.9461558411',
#                                                 'kilometers_per_second': '17.5124850433',
#                                                 'miles_per_hour': '39173.6777933336'}},
#                          {'close_approach_date': '2055-02-02',
#                           'close_approach_date_full': '2055-Feb-02 06:36',
#                           'epoch_date_close_approach': 2685162960000,
#                           'miss_distance': {'astronomical': '0.267374613',
#                                             'kilometers': '39998672.59687431',
#                                             'lunar': '104.008724457',
#                                             'miles': '24854022.655353078'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62380.0746137747',
#                                                 'kilometers_per_second': '17.3277985038',
#                                                 'miles_per_hour': '38760.5524732091'}},
#                          {'close_approach_date': '2055-08-20',
#                           'close_approach_date_full': '2055-Aug-20 22:20',
#                           'epoch_date_close_approach': 2702413200000,
#                           'miss_distance': {'astronomical': '0.3913593937',
#                                             'kilometers': '58546531.702011419',
#                                             'lunar': '152.2388041493',
#                                             'miles': '36379127.8770548222'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79151.4417358786',
#                                                 'kilometers_per_second': '21.9865115933',
#                                                 'miles_per_hour': '49181.6277830519'}},
#                          {'close_approach_date': '2061-02-08',
#                           'close_approach_date_full': '2061-Feb-08 20:19',
#                           'epoch_date_close_approach': 2875119540000,
#                           'miss_distance': {'astronomical': '0.3840189617',
#                                             'kilometers': '57448418.709931579',
#                                             'lunar': '149.3833761013',
#                                             'miles': '35696792.1041066302'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65959.7593346143',
#                                                 'kilometers_per_second': '18.3221553707',
#                                                 'miles_per_hour': '40984.8293487774'}},
#                          {'close_approach_date': '2061-08-05',
#                           'close_approach_date_full': '2061-Aug-05 22:04',
#                           'epoch_date_close_approach': 2890505040000,
#                           'miss_distance': {'astronomical': '0.0696175865',
#                                             'kilometers': '10414642.654940755',
#                                             'lunar': '27.0812411485',
#                                             'miles': '6471358.864882219'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66690.8539918261',
#                                                 'kilometers_per_second': '18.52523722',
#                                                 'miles_per_hour': '41439.10313731'}},
#                          {'close_approach_date': '2067-07-23',
#                           'close_approach_date_full': '2067-Jul-23 06:34',
#                           'epoch_date_close_approach': 3078628440000,
#                           'miss_distance': {'astronomical': '0.2448666551',
#                                             'kilometers': '36631530.036984637',
#                                             'lunar': '95.2531288339',
#                                             'miles': '22761777.2873445106'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69812.1028877508',
#                                                 'kilometers_per_second': '19.3922508022',
#                                                 'miles_per_hour': '43378.525819336'}},
#                          {'close_approach_date': '2068-01-21',
#                           'close_approach_date_full': '2068-Jan-21 13:17',
#                           'epoch_date_close_approach': 3094377420000,
#                           'miss_distance': {'astronomical': '0.4161522425',
#                                             'kilometers': '62255489.073723475',
#                                             'lunar': '161.8832223325',
#                                             'miles': '38683767.120294955'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64876.9479155226',
#                                                 'kilometers_per_second': '18.021374421',
#                                                 'miles_per_hour': '40312.0124422868'}},
#                          {'close_approach_date': '2074-01-28',
#                           'close_approach_date_full': '2074-Jan-28 19:46',
#                           'epoch_date_close_approach': 3284394360000,
#                           'miss_distance': {'astronomical': '0.2819974753',
#                                             'kilometers': '42186221.650257611',
#                                             'lunar': '109.6970178917',
#                                             'miles': '26213302.6064765918'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62309.195545036',
#                                                 'kilometers_per_second': '17.3081098736',
#                                                 'miles_per_hour': '38716.510976303'}},
#                          {'close_approach_date': '2080-02-05',
#                           'close_approach_date_full': '2080-Feb-05 07:38',
#                           'epoch_date_close_approach': 3474344280000,
#                           'miss_distance': {'astronomical': '0.2952408626',
#                                             'kilometers': '44167404.181922662',
#                                             'lunar': '114.8486955514',
#                                             'miles': '27444352.3471182556'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63166.1120299267',
#                                                 'kilometers_per_second': '17.5461422305',
#                                                 'miles_per_hour': '39248.9655554842'}},
#                          {'close_approach_date': '2080-08-14',
#                           'close_approach_date_full': '2080-Aug-14 21:23',
#                           'epoch_date_close_approach': 3490896180000,
#                           'miss_distance': {'astronomical': '0.2713191423',
#                                             'kilometers': '40588765.778306901',
#                                             'lunar': '105.5431463547',
#                                             'miles': '25220689.5557251938'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72940.2817883915',
#                                                 'kilometers_per_second': '20.2611893857',
#                                                 'miles_per_hour': '45322.2545367925'}},
#                          {'close_approach_date': '2086-02-11',
#                           'close_approach_date_full': '2086-Feb-11 14:13',
#                           'epoch_date_close_approach': 3664275180000,
#                           'miss_distance': {'astronomical': '0.4457773235',
#                                             'kilometers': '66687338.089900945',
#                                             'lunar': '173.4073788415',
#                                             'miles': '41437590.402465241'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68175.9044230014',
#                                                 'kilometers_per_second': '18.9377512286',
#                                                 'miles_per_hour': '42361.8557232811'}},
#                          {'close_approach_date': '2086-08-01',
#                           'close_approach_date_full': '2086-Aug-01 09:43',
#                           'epoch_date_close_approach': 3679033380000,
#                           'miss_distance': {'astronomical': '0.0452422205',
#                                             'kilometers': '6768139.820870335',
#                                             'lunar': '17.5992237745',
#                                             'miles': '4205527.071807223'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66023.4755503566',
#                                                 'kilometers_per_second': '18.3398543195',
#                                                 'miles_per_hour': '41024.4201273869'}},
#                          {'close_approach_date': '2092-07-16',
#                           'close_approach_date_full': '2092-Jul-16 15:15',
#                           'epoch_date_close_approach': 3867059700000,
#                           'miss_distance': {'astronomical': '0.373676568',
#                                             'kilometers': '55901218.64171016',
#                                             'lunar': '145.360184952',
#                                             'miles': '34735406.561753808'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '75310.1780388692',
#                                                 'kilometers_per_second': '20.9194938997',
#                                                 'miles_per_hour': '46794.8159042074'}},
#                          {'close_approach_date': '2093-01-24',
#                           'close_approach_date_full': '2093-Jan-24 07:58',
#                           'epoch_date_close_approach': 3883622280000,
#                           'miss_distance': {'astronomical': '0.3482981534',
#                                             'kilometers': '52104661.873573258',
#                                             'lunar': '135.4879816726',
#                                             'miles': '32376335.5776086404'},
#                           'orbiting_body': 'Earth',
# ...
#                                             'kilometers': '40313191.302623309',
#                                             'lunar': '104.8265688323',
#                                             'miles': '25049455.5167633042'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '70740.3450596926',
#                                                 'kilometers_per_second': '19.6500958499',
#                                                 'miles_per_hour': '43955.299406674'}},
#                          {'close_approach_date': '2156-01-23',
#                           'close_approach_date_full': '2156-Jan-23 14:03',
#                           'epoch_date_close_approach': 5871535380000,
#                           'miss_distance': {'astronomical': '0.4009209804',
#                                             'kilometers': '59976924.706151748',
#                                             'lunar': '155.9582613756',
#                                             'miles': '37267932.8753922024'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64599.6870747925',
#                                                 'kilometers_per_second': '17.9443575208',
#                                                 'miles_per_hour': '40139.7333382232'}},
#                          {'close_approach_date': '2162-01-30',
#                           'close_approach_date_full': '2162-Jan-30 23:42',
#                           'epoch_date_close_approach': 6061563720000,
#                           'miss_distance': {'astronomical': '0.2736152223',
#                                             'kilometers': '40932254.455656501',
#                                             'lunar': '106.4363214747',
#                                             'miles': '25434123.5227656738'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62168.8181789941',
#                                                 'kilometers_per_second': '17.2691161608',
#                                                 'miles_per_hour': '38629.2859401644'}},
#                          {'close_approach_date': '2168-02-07',
#                           'close_approach_date_full': '2168-Feb-07 15:20',
#                           'epoch_date_close_approach': 6251527200000,
#                           'miss_distance': {'astronomical': '0.3115811632',
#                                             'kilometers': '46611878.346842384',
#                                             'lunar': '121.2050724848',
#                                             'miles': '28963278.1596735392'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63683.7735981773',
#                                                 'kilometers_per_second': '17.6899371106',
#                                                 'miles_per_hour': '39570.6203227119'}},
#                          {'close_approach_date': '2168-08-14',
#                           'close_approach_date_full': '2168-Aug-14 03:48',
#                           'epoch_date_close_approach': 6267815280000,
#                           'miss_distance': {'astronomical': '0.2262109783',
#                                             'kilometers': '33840680.524296221',
#                                             'lunar': '87.9960705587',
#                                             'miles': '21027623.8139250098'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71017.4737283854',
#                                                 'kilometers_per_second': '19.7270760357',
#                                                 'miles_per_hour': '44127.4963841737'}},
#                          {'close_approach_date': '2174-02-14',
#                           'close_approach_date_full': '2174-Feb-14 01:33',
#                           'epoch_date_close_approach': 6441471180000,
#                           'miss_distance': {'astronomical': '0.4791296387',
#                                             'kilometers': '71676773.403389569',
#                                             'lunar': '186.3814294543',
#                                             'miles': '44537881.7438472922'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69427.4299662456',
#                                                 'kilometers_per_second': '19.2853972128',
#                                                 'miles_per_hour': '43139.5050254152'}},
#                          {'close_approach_date': '2174-07-31',
#                           'close_approach_date_full': '2174-Jul-31 05:31',
#                           'epoch_date_close_approach': 6455914260000,
#                           'miss_distance': {'astronomical': '0.0966027069',
#                                             'kilometers': '14451559.188474303',
#                                             'lunar': '37.5784529841',
#                                             'miles': '8979782.4816712614'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66394.6941906932',
#                                                 'kilometers_per_second': '18.4429706085',
#                                                 'miles_per_hour': '41255.0809542116'}},
#                          {'close_approach_date': '2175-01-18',
#                           'close_approach_date_full': '2175-Jan-18 12:53',
#                           'epoch_date_close_approach': 6470715180000,
#                           'miss_distance': {'astronomical': '0.4986766674',
#                                             'kilometers': '74600967.261738438',
#                                             'lunar': '193.9852236186',
#                                             'miles': '46354891.5515609244'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '67042.6137725306',
#                                                 'kilometers_per_second': '18.6229482701',
#                                                 'miles_per_hour': '41657.6729854927'}},
#                          {'close_approach_date': '2180-07-15',
#                           'close_approach_date_full': '2180-Jul-15 14:12',
#                           'epoch_date_close_approach': 6643951920000,
#                           'miss_distance': {'astronomical': '0.4238258504',
#                                             'kilometers': '63403444.470778648',
#                                             'lunar': '164.8682558056',
#                                             'miles': '39397073.5275674224'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78041.643571962',
#                                                 'kilometers_per_second': '21.6782343255',
#                                                 'miles_per_hour': '48492.0423628116'}},
#                          {'close_approach_date': '2181-01-26',
#                           'close_approach_date_full': '2181-Jan-26 22:04',
#                           'epoch_date_close_approach': 6660828240000,
#                           'miss_distance': {'astronomical': '0.3248092382',
#                                             'kilometers': '48590770.191042634',
#                                             'lunar': '126.3507936598',
#                                             'miles': '30192904.5331269892'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62982.9444397896',
#                                                 'kilometers_per_second': '17.4952623444',
#                                                 'miles_per_hour': '39135.152338157'}},
#                          {'close_approach_date': '2187-02-04',
#                           'close_approach_date_full': '2187-Feb-04 00:45',
#                           'epoch_date_close_approach': 6850831500000,
#                           'miss_distance': {'astronomical': '0.2689428736',
#                                             'kilometers': '40233281.042239232',
#                                             'lunar': '104.6187778304',
#                                             'miles': '24999801.5834441216'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '62438.5405820434',
#                                                 'kilometers_per_second': '17.3440390506',
#                                                 'miles_per_hour': '38796.8809522147'}},
#                          {'close_approach_date': '2187-08-21',
#                           'close_approach_date_full': '2187-Aug-21 23:18',
#                           'epoch_date_close_approach': 6868019880000,
#                           'miss_distance': {'astronomical': '0.3818441691',
#                                             'kilometers': '57123074.369279817',
#                                             'lunar': '148.5373817799',
#                                             'miles': '35494632.5050907946'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78519.709166652',
#                                                 'kilometers_per_second': '21.8110303241',
#                                                 'miles_per_hour': '48789.0937319122'}},
#                          {'close_approach_date': '2193-02-10',
#                           'close_approach_date_full': '2193-Feb-10 16:06',
#                           'epoch_date_close_approach': 7040793960000,
#                           'miss_distance': {'astronomical': '0.3935579469',
#                                             'kilometers': '58875430.577813103',
#                                             'lunar': '153.0940413441',
#                                             'miles': '36583496.1617947014'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66230.8334483681',
#                                                 'kilometers_per_second': '18.3974537357',
#                                                 'miles_per_hour': '41153.2642612929'}},
#                          {'close_approach_date': '2193-08-06',
#                           'close_approach_date_full': '2193-Aug-06 17:03',
#                           'epoch_date_close_approach': 7056090180000,
#                           'miss_distance': {'astronomical': '0.0565701609',
#                                             'kilometers': '8462775.576197283',
#                                             'lunar': '22.0057925901',
#                                             'miles': '5258524.9020091854'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66487.745682004',
#                                                 'kilometers_per_second': '18.468818245',
#                                                 'miles_per_hour': '41312.899532243'}},
#                          {'close_approach_date': '2199-07-24',
#                           'close_approach_date_full': '2199-Jul-24 00:28',
#                           'epoch_date_close_approach': 7244209680000,
#                           'miss_distance': {'astronomical': '0.260026138',
#                                             'kilometers': '38899356.38912606',
#                                             'lunar': '101.150167682',
#                                             'miles': '24170939.238857228'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '70394.8584825947',
#                                                 'kilometers_per_second': '19.5541273563',
#                                                 'miles_per_hour': '43740.6274832545'}},
#                          {'close_approach_date': '2200-01-23',
#                           'close_approach_date_full': '2200-Jan-23 11:39',
#                           'epoch_date_close_approach': 7260061140000,
#                           'miss_distance': {'astronomical': '0.4058045226',
#                                             'kilometers': '60707492.217326862',
#                                             'lunar': '157.8579592914',
#                                             'miles': '37721886.4767282156'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64683.7673642287',
#                                                 'kilometers_per_second': '17.9677131567',
#                                                 'miles_per_hour': '40191.9775602898'}}],
#  'designation': '2011 CC22',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 1086.4882401667,
#                                  'estimated_diameter_min': 485.8923123534},
#                         'kilometers': {'estimated_diameter_max': 0.331161605,
#                                        'estimated_diameter_min': 0.1480999721},
#                         'meters': {'estimated_diameter_max': 331.1616050056,
#                                    'estimated_diameter_min': 148.0999720661},
#                         'miles': {'estimated_diameter_max': 0.2057742177,
#                                   'estimated_diameter_min': 0.0920250277}},
#  'id': '3557196',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3557196?api_key=DEMO_KEY'},
#  'name': '(2011 CC22)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3557196',
#  'neo_reference_id': '3557196',
#  'orbital_data': {'aphelion_distance': '1.251993018112079',
#                   'ascending_node_longitude': '130.3160265171074',
#                   'data_arc_in_days': 4721,
#                   'eccentricity': '.1152699054032185',
#                   'epoch_osculation': '2460200.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '2011-02-06',
#                   'inclination': '34.8234876130463',
#                   'jupiter_tisserand_invariant': '5.393',
#                   'last_observation_date': '2024-01-10',
#                   'mean_anomaly': '54.84613113977929',
#                   'mean_motion': '.8286501024002261',
#                   'minimum_orbit_intersection': '.0205337',
#                   'observations_used': 57,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2024-01-10 05:22:46',
#                   'orbit_id': '13',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '434.4415078900517',
#                   'perihelion_argument': '171.2840900424482',
#                   'perihelion_distance': '.993190882298879',
#                   'perihelion_time': '2460134.312678015830',
#                   'semi_major_axis': '1.122591950205479'}}

# %% [markdown]
# Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
ca_list = data['close_approach_data']
min_dist_entry = min([(float(entry['miss_distance']['kilometers']), entry['close_approach_date']) for entry in ca_list]) #I got the for-loop code from Cole, and then I turned it into a list comprehension

min_dist, min_dist_date = min_dist_entry
print(min_dist, min_dist_date)
# Out:
# 4559141.619363665 1954-08-01

# %% [markdown]
# ## Challenge - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# Ex. 3 (challenge) your code here
